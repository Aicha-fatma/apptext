# %%
import pandas as pd

# %%
df = pd.read_csv("MOCK_DATA (3).csv")

# %%
df
# Out:
#        id first_name last_name                      email  gender  \
# 0       1    Cathrin     Prout            cprout0@ted.com    Male
# 1       2       Dana       Ive              dive1@msn.com  Female
# 2       3    Bernarr    Jeduch           bjeduch2@gnu.org  Female
# 3       4      Gunar     Pudge          gpudge3@alexa.com    Male
# 4       5       Bink   O'Regan      boregan4@hatena.ne.jp    Male
# ..    ...        ...       ...                        ...     ...
# 995   996     Maddie   Averies    maveriesrn@bluehost.com    Male
# 996   997     Corney  Eidelman  ceidelmanro@princeton.edu  Female
# 997   998    Averill     Dearn             adearnrp@ow.ly  Female
# 998   999     Porter    Kervin        pkervinrq@wikia.com  Female
# 999  1000      Aimee    Salmen      asalmenrr@pcworld.com    Male
#
#           ip_address
# 0       8.26.130.166
# 1      181.74.57.165
# 2    147.151.191.247
# 3      106.131.32.82
# 4      88.139.222.13
# ..               ...
# ...
